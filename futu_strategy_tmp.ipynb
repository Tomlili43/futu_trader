# %%
from futu import *

############################ 全局变量设置 ############################
FUTUOPEND_ADDRESS = '127.0.0.1'  # Futu OpenD 监听地址
FUTUOPEND_PORT = 11111  # Futu OpenD 监听端口

TRADING_ENVIRONMENT = TrdEnv.SIMULATE  # 交易环境：真实 / 模拟
TRADING_MARKET = TrdMarket.HK  # 交易市场权限，用于筛选对应交易市场权限的账户
TRADING_PWD = '123456'  # 交易密码，用于解锁交易
TRADING_PERIOD = KLType.K_1M  # 信号 K 线周期
TRADING_SECURITY = 'HK.09988'  # 交易标的
FAST_MOVING_AVERAGE = 1  # 均线快线的周期
SLOW_MOVING_AVERAGE = 3  # 均线慢线的周期

quote_context = OpenQuoteContext(host=FUTUOPEND_ADDRESS, port=FUTUOPEND_PORT)  # 行情对象
trade_context = OpenSecTradeContext(filter_trdmarket=TRADING_MARKET, host=FUTUOPEND_ADDRESS, port=FUTUOPEND_PORT, security_firm=SecurityFirm.FUTUSECURITIES)  # 交易对象，根据交易品种修改交易对象类型


# 解锁交易
def unlock_trade():
    if TRADING_ENVIRONMENT == TrdEnv.REAL:
        ret, data = trade_context.unlock_trade(TRADING_PWD)
        if ret != RET_OK:
            print('解锁交易失败：', data)
            return False
        print('解锁交易成功！')
    return True


# 获取市场状态
def is_normal_trading_time(code):
    ret, data = quote_context.get_market_state([code])
    if ret != RET_OK:
        print('获取市场状态失败：', data)
        return False
    market_state = data['market_state'][0]
    '''
    MarketState.MORNING            港、A 股早盘
    MarketState.AFTERNOON          港、A 股下午盘，美股全天
    MarketState.FUTURE_DAY_OPEN    港、新、日期货日市开盘
    MarketState.FUTURE_OPEN        美期货开盘
    MarketState.NIGHT_OPEN         港、新、日期货夜市开盘
    '''
    if market_state == MarketState.MORNING or \
                    market_state == MarketState.AFTERNOON or \
                    market_state == MarketState.FUTURE_DAY_OPEN  or \
                    market_state == MarketState.FUTURE_OPEN  or \
                    market_state == MarketState.NIGHT_OPEN:
        return True
    print('现在不是持续交易时段。')
    return False


# 获取持仓数量
def get_holding_position(code):
    holding_position = 0
    ret, data = trade_context.position_list_query(code=code, trd_env=TRADING_ENVIRONMENT)
    if ret != RET_OK:
        print('获取持仓数据失败：', data)
        return None
    else:
        for qty in data['qty'].values.tolist():
            holding_position += qty
        print('【持仓状态】 {} 的持仓数量为：{}'.format(TRADING_SECURITY, holding_position))
    return holding_position


# 拉取 K 线，计算均线，判断多空
def calculate_bull_bear(code, fast_param, slow_param):
    if fast_param <= 0 or slow_param <= 0:
        return 0
    if fast_param > slow_param:
        return calculate_bull_bear(code, slow_param, fast_param)
    ret, data = quote_context.get_cur_kline(code=code, num=slow_param + 1, ktype=TRADING_PERIOD)
    if ret != RET_OK:
        print('获取K线失败：', data)
        return 0
    candlestick_list = data['close'].values.tolist()[::-1]
    fast_value = None
    slow_value = None
    if len(candlestick_list) > fast_param:
        fast_value = sum(candlestick_list[1: fast_param + 1]) / fast_param
    if len(candlestick_list) > slow_param:
        slow_value = sum(candlestick_list[1: slow_param + 1]) / slow_param
    if fast_value is None or slow_value is None:
        return 0
    return 1 if fast_value >= slow_value else -1


# 获取一档摆盘的 ask1 和 bid1
def get_ask_and_bid(code):
    ret, data = quote_context.get_order_book(code, num=1)
    if ret != RET_OK:
        print('获取摆盘数据失败：', data)
        return None, None
    return data['Ask'][0][0], data['Bid'][0][0]


# 开仓函数
def open_position(code):
    # 获取摆盘数据
    ask, bid = get_ask_and_bid(code)

    # 计算下单量
    open_quantity = calculate_quantity()

    # 判断购买力是否足够
    if is_valid_quantity(TRADING_SECURITY, open_quantity, ask):
        # 下单
        ret, data = trade_context.place_order(price=ask, qty=open_quantity, code=code, trd_side=TrdSide.BUY,
                                              order_type=OrderType.NORMAL, trd_env=TRADING_ENVIRONMENT,
                                              remark='moving_average_strategy')
        if ret != RET_OK:
            print('开仓失败：', data)
    else:
        print('下单数量超出最大可买数量。')


# 平仓函数
def close_position(code, quantity):
    # 获取摆盘数据
    ask, bid = get_ask_and_bid(code)

    # 检查平仓数量
    if quantity == 0:
        print('无效的下单数量。')
        return False

    # 平仓
    ret, data = trade_context.place_order(price=bid, qty=quantity, code=code, trd_side=TrdSide.SELL,
                   order_type=OrderType.NORMAL, trd_env=TRADING_ENVIRONMENT, remark='moving_average_strategy')
    if ret != RET_OK:
        print('平仓失败：', data)
        return False
    return True


# 计算下单数量
def calculate_quantity():
    price_quantity = 0
    # 使用最小交易量
    ret, data = quote_context.get_market_snapshot([TRADING_SECURITY])
    if ret != RET_OK:
        print('获取快照失败：', data)
        return price_quantity
    price_quantity = data['lot_size'][0]
    return price_quantity


# 判断购买力是否足够
def is_valid_quantity(code, quantity, price):
    ret, data = trade_context.acctradinginfo_query(order_type=OrderType.NORMAL, code=code, price=price,
                                                   trd_env=TRADING_ENVIRONMENT)
    if ret != RET_OK:
        print('获取最大可买可卖失败：', data)
        return False
    max_can_buy = data['max_cash_buy'][0]
    max_can_sell = data['max_sell_short'][0]
    if quantity > 0:
        return quantity < max_can_buy
    elif quantity < 0:
        return abs(quantity) < max_can_sell
    else:
        return False


# 展示订单回调
def show_order_status(data):
    order_status = data['order_status'][0]
    order_info = dict()
    order_info['代码'] = data['code'][0]
    order_info['价格'] = data['price'][0]
    order_info['方向'] = data['trd_side'][0]
    order_info['数量'] = data['qty'][0]
    print('【订单状态】', order_status, order_info)


############################ 填充以下函数来完成您的策略 ############################
# 策略启动时运行一次，用于初始化策略
def on_init():
    # 解锁交易（如果是模拟交易则不需要解锁）
    if not unlock_trade():
        return False
    print('************  策略开始运行 ***********')
    return True


# 每个 tick 运行一次，可将策略的主要逻辑写在此处
def on_tick():
    pass


# 每次产生一根新的 K 线运行一次，可将策略的主要逻辑写在此处
def on_bar_open():
    # 打印分隔线
    print('*************************************')

    # 只在常规交易时段交易
    if not is_normal_trading_time(TRADING_SECURITY):
        return

    # 获取 K 线，计算均线，判断多空
    bull_or_bear = calculate_bull_bear(TRADING_SECURITY, FAST_MOVING_AVERAGE, SLOW_MOVING_AVERAGE)

    # 获取持仓数量
    holding_position = get_holding_position(TRADING_SECURITY)

    # 下单判断
    if holding_position == 0:
        if bull_or_bear == 1:
            print('【操作信号】 做多信号，建立多单。')
            open_position(TRADING_SECURITY)
        else:
            print('【操作信号】 做空信号，不开空单。')
    elif holding_position > 0:
        if bull_or_bear == -1:
            print('【操作信号】 做空信号，平掉持仓。')
            close_position(TRADING_SECURITY, holding_position)
        else:
            print('【操作信号】 做多信号，无需加仓。')


# 委托成交有变化时运行一次
def on_fill(data):
    pass


# 订单状态有变化时运行一次
def on_order_status(data):
    if data['code'][0] == TRADING_SECURITY:
        show_order_status(data)


################################ 框架实现部分，可忽略不看 ###############################
class OnTickClass(TickerHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        on_tick()


class OnBarClass(CurKlineHandlerBase):
    last_time = None
    def on_recv_rsp(self, rsp_pb):
        ret_code, data = super(OnBarClass, self).on_recv_rsp(rsp_pb)
        if ret_code == RET_OK:
            cur_time = data['time_key'][0]
            if cur_time != self.last_time and data['k_type'][0] == TRADING_PERIOD:
                if self.last_time is not None:
                    on_bar_open()
                self.last_time = cur_time


class OnOrderClass  (TradeOrderHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        ret, data = super(OnOrderClass, self).on_recv_rsp(rsp_pb)
        if ret == RET_OK:
            on_order_status( data)


class OnFillClass(TradeDealHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        ret, data = super(OnFillClass, self).on_recv_rsp(rsp_pb)
        if ret == RET_OK:
            on_fill(data)

class StockQuoteClass(StockQuoteHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        ret_code, data = super(StockQuoteClass,self).on_recv_rsp(rsp_pb)
        if ret_code != RET_OK:
            print("StockQuoteClass: error, msg: %s"% data)
            return RET_ERROR, data
        #  print("StockQuoteClass ", data) # StockQuoteClass's own processing logic
        print("last_price:", data['last_price'])
        print("type:last_price:", type(data['last_price']))
        last_price = data['last_price'].values[0]
        if(last_price < 89.0):
            print("last_price < 89")
        return RET_OK, data

# 主函数
if __name__ == '__main__':
    # 初始化策略
    if not on_init():
        print('策略初始化失败，脚本退出！')
        quote_context.close()
        trade_context.close()
    else:
        # 设置回调
        # quote_context.set_handler(OnTickClass())
        quote_context.set_handler(StockQuoteClass())

        # quote_context.set_handler(OnBarClass())
        trade_context.set_handler(OnOrderClass())
        trade_context.set_handler(OnFillClass())

        # 订阅标的合约的 逐笔，K 线和摆盘，以便获取数据
        quote_context.subscribe(code_list=[TRADING_SECURITY], subtype_list=[SubType.TICKER, SubType.ORDER_BOOK, TRADING_PERIOD])
# Out:
# 2023-08-25 13:53:47,946 | 17182 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1, host=127.0.0.1, port=11111, user_id=28749530
# 2023-08-25 13:53:47,948 | 17182 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=2, host=127.0.0.1, port=11111, user_id=28749530
# ************  策略开始运行 ***********
# 2023-08-25 16:33:35,565 | 17182 | [open_context_base.py] on_disconnect:386: Disconnected: conn_id=1 reason=CloseReason.RemoteClose msg=
# 2023-08-25 16:33:35,570 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:33:35,572 | 17182 | [open_context_base.py] on_disconnect:386: Disconnected: conn_id=2 reason=CloseReason.RemoteClose msg=
# 2023-08-25 16:33:35,572 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:33:43,574 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=3; msg=ECONNREFUSED
# 2023-08-25 16:33:43,576 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:33:43,578 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=4; msg=ECONNREFUSED
# 2023-08-25 16:33:43,581 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:33:51,581 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=5; msg=ECONNREFUSED
# 2023-08-25 16:33:51,583 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:33:51,587 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=6; msg=ECONNREFUSED
# 2023-08-25 16:33:51,588 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:33:59,590 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=7; msg=ECONNREFUSED
# 2023-08-25 16:33:59,592 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:33:59,593 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=8; msg=ECONNREFUSED
# 2023-08-25 16:33:59,594 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:07,596 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=9; msg=ECONNREFUSED
# 2023-08-25 16:34:07,599 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=10; msg=ECONNREFUSED
# 2023-08-25 16:34:07,599 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:07,600 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:15,607 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=11; msg=ECONNREFUSED
# 2023-08-25 16:34:15,609 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:15,611 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=12; msg=ECONNREFUSED
# 2023-08-25 16:34:15,614 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:23,618 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=13; msg=ECONNREFUSED
# 2023-08-25 16:34:23,620 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:23,622 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=14; msg=ECONNREFUSED
# 2023-08-25 16:34:23,623 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:31,626 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=15; msg=ECONNREFUSED
# 2023-08-25 16:34:31,629 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:31,630 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=16; msg=ECONNREFUSED
# 2023-08-25 16:34:31,631 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:39,637 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=18; msg=ECONNREFUSED
# 2023-08-25 16:34:39,638 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=17; msg=ECONNREFUSED
# 2023-08-25 16:34:39,639 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:39,640 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:47,643 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=19; msg=ECONNREFUSED
# 2023-08-25 16:34:47,644 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:47,645 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=20; msg=ECONNREFUSED
# 2023-08-25 16:34:47,647 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:55,652 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=22; msg=ECONNREFUSED
# 2023-08-25 16:34:55,655 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:34:55,655 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=21; msg=ECONNREFUSED
# 2023-08-25 16:34:55,657 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:03,660 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=23; msg=ECONNREFUSED
# 2023-08-25 16:35:03,662 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:03,665 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=24; msg=ECONNREFUSED
# 2023-08-25 16:35:03,666 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:11,670 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=25; msg=ECONNREFUSED
# 2023-08-25 16:35:11,673 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:11,674 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=26; msg=ECONNREFUSED
# 2023-08-25 16:35:11,676 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:19,681 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=27; msg=ECONNREFUSED
# 2023-08-25 16:35:19,683 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=28; msg=ECONNREFUSED
# 2023-08-25 16:35:19,684 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:19,684 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:27,692 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=29; msg=ECONNREFUSED
# 2023-08-25 16:35:27,694 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=30; msg=ECONNREFUSED
# 2023-08-25 16:35:27,694 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:27,697 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:35,704 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=31; msg=ECONNREFUSED
# 2023-08-25 16:35:35,707 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:35,708 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=32; msg=ECONNREFUSED
# 2023-08-25 16:35:35,710 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:43,713 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=33; msg=ECONNREFUSED
# 2023-08-25 16:35:43,716 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:43,718 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=34; msg=ECONNREFUSED
# 2023-08-25 16:35:43,720 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:51,724 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=35; msg=ECONNREFUSED
# 2023-08-25 16:35:51,727 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:51,729 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=36; msg=ECONNREFUSED
# 2023-08-25 16:35:51,731 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:59,736 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=37; msg=ECONNREFUSED
# 2023-08-25 16:35:59,739 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:35:59,740 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=38; msg=ECONNREFUSED
# 2023-08-25 16:35:59,743 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:07,747 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=39; msg=ECONNREFUSED
# 2023-08-25 16:36:07,749 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:07,754 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=40; msg=ECONNREFUSED
# 2023-08-25 16:36:07,756 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:15,757 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=41; msg=ECONNREFUSED
# 2023-08-25 16:36:15,760 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:15,763 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=42; msg=ECONNREFUSED
# 2023-08-25 16:36:15,764 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:23,769 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=43; msg=ECONNREFUSED
# 2023-08-25 16:36:23,770 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:23,771 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=44; msg=ECONNREFUSED
# 2023-08-25 16:36:23,772 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:31,777 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=45; msg=ECONNREFUSED
# 2023-08-25 16:36:31,780 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:31,783 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=46; msg=ECONNREFUSED
# 2023-08-25 16:36:31,785 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:39,787 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=47; msg=ECONNREFUSED
# 2023-08-25 16:36:39,790 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:39,793 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=48; msg=ECONNREFUSED
# 2023-08-25 16:36:39,795 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:47,799 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=49; msg=ECONNREFUSED
# 2023-08-25 16:36:47,802 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:47,802 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=50; msg=ECONNREFUSED
# 2023-08-25 16:36:47,804 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:55,809 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=51; msg=ECONNREFUSED
# 2023-08-25 16:36:55,810 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:36:55,811 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=52; msg=ECONNREFUSED
# 2023-08-25 16:36:55,813 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:03,818 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=53; msg=ECONNREFUSED
# 2023-08-25 16:37:03,819 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:03,820 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=54; msg=ECONNREFUSED
# 2023-08-25 16:37:03,821 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:11,826 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=55; msg=ECONNREFUSED
# 2023-08-25 16:37:11,828 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:11,829 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=56; msg=ECONNREFUSED
# 2023-08-25 16:37:11,831 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:19,834 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=57; msg=ECONNREFUSED
# 2023-08-25 16:37:19,836 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:19,838 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=58; msg=ECONNREFUSED
# 2023-08-25 16:37:19,839 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:27,844 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=59; msg=ECONNREFUSED
# 2023-08-25 16:37:27,846 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=60; msg=ECONNREFUSED
# 2023-08-25 16:37:27,846 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:27,848 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:35,851 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=61; msg=ECONNREFUSED
# 2023-08-25 16:37:35,852 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:35,854 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=62; msg=ECONNREFUSED
# 2023-08-25 16:37:35,855 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:43,860 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=63; msg=ECONNREFUSED
# 2023-08-25 16:37:43,863 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:43,864 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=64; msg=ECONNREFUSED
# 2023-08-25 16:37:43,866 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:51,871 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=65; msg=ECONNREFUSED
# 2023-08-25 16:37:51,873 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=66; msg=ECONNREFUSED
# 2023-08-25 16:37:51,874 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:51,877 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:59,883 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=67; msg=ECONNREFUSED
# 2023-08-25 16:37:59,885 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:37:59,887 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=68; msg=ECONNREFUSED
# 2023-08-25 16:37:59,888 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:07,893 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=69; msg=ECONNREFUSED
# 2023-08-25 16:38:07,894 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=70; msg=ECONNREFUSED
# 2023-08-25 16:38:07,895 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:07,896 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:15,899 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=71; msg=ECONNREFUSED
# 2023-08-25 16:38:15,901 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=72; msg=ECONNREFUSED
# 2023-08-25 16:38:15,902 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:15,902 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:23,910 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=73; msg=ECONNREFUSED
# 2023-08-25 16:38:23,911 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=74; msg=ECONNREFUSED
# 2023-08-25 16:38:23,912 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:23,914 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:31,922 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=76; msg=ECONNREFUSED
# 2023-08-25 16:38:31,923 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=75; msg=ECONNREFUSED
# 2023-08-25 16:38:31,925 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:31,926 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:39,931 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=77; msg=ECONNREFUSED
# 2023-08-25 16:38:39,934 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:39,935 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=78; msg=ECONNREFUSED
# 2023-08-25 16:38:39,938 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:47,943 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=80; msg=ECONNREFUSED
# 2023-08-25 16:38:47,945 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:47,945 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=79; msg=ECONNREFUSED
# 2023-08-25 16:38:47,948 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:55,953 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=81; msg=ECONNREFUSED
# 2023-08-25 16:38:55,956 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:38:55,959 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=82; msg=ECONNREFUSED
# 2023-08-25 16:38:55,960 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:03,964 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=83; msg=ECONNREFUSED
# 2023-08-25 16:39:03,966 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=84; msg=ECONNREFUSED
# 2023-08-25 16:39:03,966 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:03,968 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:11,976 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=85; msg=ECONNREFUSED
# 2023-08-25 16:39:11,978 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:11,978 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=86; msg=ECONNREFUSED
# 2023-08-25 16:39:11,982 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:19,987 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=87; msg=ECONNREFUSED
# 2023-08-25 16:39:19,988 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=88; msg=ECONNREFUSED
# 2023-08-25 16:39:19,990 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:19,991 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:27,999 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=89; msg=ECONNREFUSED
# 2023-08-25 16:39:28,002 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=90; msg=ECONNREFUSED
# 2023-08-25 16:39:28,002 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:28,003 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:36,009 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=91; msg=ECONNREFUSED
# 2023-08-25 16:39:36,011 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:36,013 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=92; msg=ECONNREFUSED
# 2023-08-25 16:39:36,014 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:44,016 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=93; msg=ECONNREFUSED
# 2023-08-25 16:39:44,019 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:44,020 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=94; msg=ECONNREFUSED
# 2023-08-25 16:39:44,022 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:52,023 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=95; msg=ECONNREFUSED
# 2023-08-25 16:39:52,026 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:39:52,027 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=96; msg=ECONNREFUSED
# 2023-08-25 16:39:52,030 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:00,030 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=97; msg=ECONNREFUSED
# 2023-08-25 16:40:00,033 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:00,036 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=98; msg=ECONNREFUSED
# 2023-08-25 16:40:00,038 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:08,041 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=99; msg=ECONNREFUSED
# 2023-08-25 16:40:08,044 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:08,046 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=100; msg=ECONNREFUSED
# 2023-08-25 16:40:08,047 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:16,048 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=101; msg=ECONNREFUSED
# 2023-08-25 16:40:16,051 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:16,053 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=102; msg=ECONNREFUSED
# 2023-08-25 16:40:16,055 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:24,060 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=103; msg=ECONNREFUSED
# 2023-08-25 16:40:24,062 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=104; msg=ECONNREFUSED
# 2023-08-25 16:40:24,063 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:24,064 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:32,073 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=105; msg=ECONNREFUSED
# 2023-08-25 16:40:32,075 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=106; msg=ECONNREFUSED
# 2023-08-25 16:40:32,076 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:32,077 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:40,085 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=107; msg=ECONNREFUSED
# 2023-08-25 16:40:40,088 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:40,091 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=108; msg=ECONNREFUSED
# 2023-08-25 16:40:40,093 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:48,094 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=109; msg=ECONNREFUSED
# 2023-08-25 16:40:48,097 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:48,098 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=110; msg=ECONNREFUSED
# 2023-08-25 16:40:48,100 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:56,100 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=111; msg=ECONNREFUSED
# 2023-08-25 16:40:56,103 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:40:56,108 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=112; msg=ECONNREFUSED
# 2023-08-25 16:40:56,109 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:04,107 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=113; msg=ECONNREFUSED
# 2023-08-25 16:41:04,109 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:04,115 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=114; msg=ECONNREFUSED
# 2023-08-25 16:41:04,116 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:12,117 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=115; msg=ECONNREFUSED
# 2023-08-25 16:41:12,120 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:12,123 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=116; msg=ECONNREFUSED
# 2023-08-25 16:41:12,125 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:20,127 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=117; msg=ECONNREFUSED
# 2023-08-25 16:41:20,129 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:20,131 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=118; msg=ECONNREFUSED
# 2023-08-25 16:41:20,133 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:28,139 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=119; msg=ECONNREFUSED
# 2023-08-25 16:41:28,140 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=120; msg=ECONNREFUSED
# 2023-08-25 16:41:28,141 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:28,143 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:36,149 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=121; msg=ECONNREFUSED
# 2023-08-25 16:41:36,151 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:36,153 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=122; msg=ECONNREFUSED
# 2023-08-25 16:41:36,155 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:44,158 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=123; msg=ECONNREFUSED
# 2023-08-25 16:41:44,160 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:44,163 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=124; msg=ECONNREFUSED
# 2023-08-25 16:41:44,164 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:52,169 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=125; msg=ECONNREFUSED
# 2023-08-25 16:41:52,172 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:41:52,174 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=126; msg=ECONNREFUSED
# 2023-08-25 16:41:52,176 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:00,180 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=127; msg=ECONNREFUSED
# 2023-08-25 16:42:00,182 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:00,182 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=128; msg=ECONNREFUSED
# 2023-08-25 16:42:00,183 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:08,188 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=129; msg=ECONNREFUSED
# 2023-08-25 16:42:08,191 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:08,193 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=130; msg=ECONNREFUSED
# 2023-08-25 16:42:08,194 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:16,200 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=131; msg=ECONNREFUSED
# 2023-08-25 16:42:16,203 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:16,203 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=132; msg=ECONNREFUSED
# 2023-08-25 16:42:16,207 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:24,207 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=133; msg=ECONNREFUSED
# 2023-08-25 16:42:24,209 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:24,210 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=134; msg=ECONNREFUSED
# 2023-08-25 16:42:24,211 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:32,212 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=135; msg=ECONNREFUSED
# 2023-08-25 16:42:32,215 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:32,217 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=136; msg=ECONNREFUSED
# 2023-08-25 16:42:32,218 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:40,223 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=137; msg=ECONNREFUSED
# 2023-08-25 16:42:40,227 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=138; msg=ECONNREFUSED
# 2023-08-25 16:42:40,228 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:40,229 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:48,238 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=139; msg=ECONNREFUSED
# 2023-08-25 16:42:48,240 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=140; msg=ECONNREFUSED
# 2023-08-25 16:42:48,241 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:48,243 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:56,249 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=141; msg=ECONNREFUSED
# 2023-08-25 16:42:56,252 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=142; msg=ECONNREFUSED
# 2023-08-25 16:42:56,253 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:42:56,254 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:04,260 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=143; msg=ECONNREFUSED
# 2023-08-25 16:43:04,263 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=144; msg=ECONNREFUSED
# 2023-08-25 16:43:04,263 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:04,264 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:12,270 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=145; msg=ECONNREFUSED
# 2023-08-25 16:43:12,272 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:12,274 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=146; msg=ECONNREFUSED
# 2023-08-25 16:43:12,275 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:20,281 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=147; msg=ECONNREFUSED
# 2023-08-25 16:43:20,283 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:20,285 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=148; msg=ECONNREFUSED
# 2023-08-25 16:43:20,288 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:28,287 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=149; msg=ECONNREFUSED
# 2023-08-25 16:43:28,289 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:28,296 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=150; msg=ECONNREFUSED
# 2023-08-25 16:43:28,298 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:36,296 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=151; msg=ECONNREFUSED
# 2023-08-25 16:43:36,297 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:36,305 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=152; msg=ECONNREFUSED
# 2023-08-25 16:43:36,306 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:44,304 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=153; msg=ECONNREFUSED
# 2023-08-25 16:43:44,306 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:44,311 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=154; msg=ECONNREFUSED
# 2023-08-25 16:43:44,312 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:52,311 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=155; msg=ECONNREFUSED
# 2023-08-25 16:43:52,313 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:43:52,316 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=156; msg=ECONNREFUSED
# 2023-08-25 16:43:52,317 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:00,320 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=157; msg=ECONNREFUSED
# 2023-08-25 16:44:00,322 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:00,323 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=158; msg=ECONNREFUSED
# 2023-08-25 16:44:00,334 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:08,337 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=159; msg=ECONNREFUSED
# 2023-08-25 16:44:08,339 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:08,341 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=160; msg=ECONNREFUSED
# 2023-08-25 16:44:08,342 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:16,347 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=161; msg=ECONNREFUSED
# 2023-08-25 16:44:16,349 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=162; msg=ECONNREFUSED
# 2023-08-25 16:44:16,349 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:16,349 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:24,352 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=163; msg=ECONNREFUSED
# 2023-08-25 16:44:24,355 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:24,356 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=164; msg=ECONNREFUSED
# 2023-08-25 16:44:24,357 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:32,362 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=165; msg=ECONNREFUSED
# 2023-08-25 16:44:32,363 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:32,364 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=166; msg=ECONNREFUSED
# 2023-08-25 16:44:32,364 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:40,367 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=167; msg=ECONNREFUSED
# 2023-08-25 16:44:40,369 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:40,370 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=168; msg=ECONNREFUSED
# 2023-08-25 16:44:40,371 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:48,375 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=169; msg=ECONNREFUSED
# 2023-08-25 16:44:48,377 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:48,378 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=170; msg=ECONNREFUSED
# 2023-08-25 16:44:48,380 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:56,385 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=171; msg=ECONNREFUSED
# 2023-08-25 16:44:56,386 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=172; msg=ECONNREFUSED
# 2023-08-25 16:44:56,387 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:44:56,387 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:04,395 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=173; msg=ECONNREFUSED
# 2023-08-25 16:45:04,397 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=174; msg=ECONNREFUSED
# 2023-08-25 16:45:04,397 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:04,398 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:12,402 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=175; msg=ECONNREFUSED
# 2023-08-25 16:45:12,403 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:12,405 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=176; msg=ECONNREFUSED
# 2023-08-25 16:45:12,406 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:20,411 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=177; msg=ECONNREFUSED
# 2023-08-25 16:45:20,414 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:20,415 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=178; msg=ECONNREFUSED
# 2023-08-25 16:45:20,417 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:28,418 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=179; msg=ECONNREFUSED
# 2023-08-25 16:45:28,421 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:28,423 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=180; msg=ECONNREFUSED
# 2023-08-25 16:45:28,424 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:36,425 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=181; msg=ECONNREFUSED
# 2023-08-25 16:45:36,427 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:36,428 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=182; msg=ECONNREFUSED
# 2023-08-25 16:45:36,430 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:44,435 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=183; msg=ECONNREFUSED
# 2023-08-25 16:45:44,438 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:44,439 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=184; msg=ECONNREFUSED
# 2023-08-25 16:45:44,442 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:52,447 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=185; msg=ECONNREFUSED
# 2023-08-25 16:45:52,450 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=186; msg=ECONNREFUSED
# 2023-08-25 16:45:52,450 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:45:52,452 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 16:46:00,460 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=187; msg=ECONNREFUSED
# 2023-08-25 16:46:00,462 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=188; msg=ECONNREFUSED
# ...
# 2023-08-25 17:40:01,359 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:09,358 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=957; msg=ECONNREFUSED
# 2023-08-25 17:40:09,360 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:09,363 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=958; msg=ECONNREFUSED
# 2023-08-25 17:40:09,365 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:17,369 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=959; msg=ECONNREFUSED
# 2023-08-25 17:40:17,371 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=960; msg=ECONNREFUSED
# 2023-08-25 17:40:17,372 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:17,373 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:25,381 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=961; msg=ECONNREFUSED
# 2023-08-25 17:40:25,383 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:25,384 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=962; msg=ECONNREFUSED
# 2023-08-25 17:40:25,388 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:33,389 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=963; msg=ECONNREFUSED
# 2023-08-25 17:40:33,391 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:33,392 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=964; msg=ECONNREFUSED
# 2023-08-25 17:40:33,393 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:41,397 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=965; msg=ECONNREFUSED
# 2023-08-25 17:40:41,399 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:41,399 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=966; msg=ECONNREFUSED
# 2023-08-25 17:40:41,402 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:49,403 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=967; msg=ECONNREFUSED
# 2023-08-25 17:40:49,405 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:49,408 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=968; msg=ECONNREFUSED
# 2023-08-25 17:40:49,409 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:57,410 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=969; msg=ECONNREFUSED
# 2023-08-25 17:40:57,411 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:40:57,414 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=970; msg=ECONNREFUSED
# 2023-08-25 17:40:57,415 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:05,414 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=971; msg=ECONNREFUSED
# 2023-08-25 17:41:05,416 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:05,419 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=972; msg=ECONNREFUSED
# 2023-08-25 17:41:05,422 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:13,424 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=973; msg=ECONNREFUSED
# 2023-08-25 17:41:13,427 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:13,430 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=974; msg=ECONNREFUSED
# 2023-08-25 17:41:13,431 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:21,433 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=975; msg=ECONNREFUSED
# 2023-08-25 17:41:21,435 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:21,438 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=976; msg=ECONNREFUSED
# 2023-08-25 17:41:21,439 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:29,444 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=977; msg=ECONNREFUSED
# 2023-08-25 17:41:29,445 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=978; msg=ECONNREFUSED
# 2023-08-25 17:41:29,446 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:29,448 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:37,454 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=979; msg=ECONNREFUSED
# 2023-08-25 17:41:37,456 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=980; msg=ECONNREFUSED
# 2023-08-25 17:41:37,457 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:37,459 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:45,468 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=981; msg=ECONNREFUSED
# 2023-08-25 17:41:45,469 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=982; msg=ECONNREFUSED
# 2023-08-25 17:41:45,470 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:45,471 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:53,475 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=983; msg=ECONNREFUSED
# 2023-08-25 17:41:53,477 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:41:53,480 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=984; msg=ECONNREFUSED
# 2023-08-25 17:41:53,482 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:01,481 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=985; msg=ECONNREFUSED
# 2023-08-25 17:42:01,483 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:01,486 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=986; msg=ECONNREFUSED
# 2023-08-25 17:42:01,488 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:09,491 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=987; msg=ECONNREFUSED
# 2023-08-25 17:42:09,493 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:09,496 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=988; msg=ECONNREFUSED
# 2023-08-25 17:42:09,498 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:17,502 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=989; msg=ECONNREFUSED
# 2023-08-25 17:42:17,504 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=990; msg=ECONNREFUSED
# 2023-08-25 17:42:17,505 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:17,506 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:25,513 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=991; msg=ECONNREFUSED
# 2023-08-25 17:42:25,517 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:25,518 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=992; msg=ECONNREFUSED
# 2023-08-25 17:42:25,520 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:33,526 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=993; msg=ECONNREFUSED
# 2023-08-25 17:42:33,528 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=994; msg=ECONNREFUSED
# 2023-08-25 17:42:33,528 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:33,530 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:41,537 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=995; msg=ECONNREFUSED
# 2023-08-25 17:42:41,539 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=996; msg=ECONNREFUSED
# 2023-08-25 17:42:41,540 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:41,542 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:49,549 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=997; msg=ECONNREFUSED
# 2023-08-25 17:42:49,551 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:49,552 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=998; msg=ECONNREFUSED
# 2023-08-25 17:42:49,555 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:57,559 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=999; msg=ECONNREFUSED
# 2023-08-25 17:42:57,562 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:42:57,565 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1000; msg=ECONNREFUSED
# 2023-08-25 17:42:57,566 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:05,569 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1001; msg=ECONNREFUSED
# 2023-08-25 17:43:05,571 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:05,575 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1002; msg=ECONNREFUSED
# 2023-08-25 17:43:05,576 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:13,580 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1003; msg=ECONNREFUSED
# 2023-08-25 17:43:13,582 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:13,585 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1004; msg=ECONNREFUSED
# 2023-08-25 17:43:13,586 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:21,591 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1005; msg=ECONNREFUSED
# 2023-08-25 17:43:21,593 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:21,593 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1006; msg=ECONNREFUSED
# 2023-08-25 17:43:21,596 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:29,595 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1007; msg=ECONNREFUSED
# 2023-08-25 17:43:29,598 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:29,598 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1008; msg=ECONNREFUSED
# 2023-08-25 17:43:29,633 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:37,632 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1010; msg=ECONNREFUSED
# 2023-08-25 17:43:37,633 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1009; msg=ECONNREFUSED
# 2023-08-25 17:43:37,633 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:37,634 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:45,633 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1011; msg=ECONNREFUSED
# 2023-08-25 17:43:45,635 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:45,635 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1012; msg=ECONNREFUSED
# 2023-08-25 17:43:45,637 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:53,640 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1013; msg=ECONNREFUSED
# 2023-08-25 17:43:53,642 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:43:53,643 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1014; msg=ECONNREFUSED
# 2023-08-25 17:43:53,646 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:44:01,650 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1015; msg=ECONNREFUSED
# 2023-08-25 17:44:01,650 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1016; msg=ECONNREFUSED
# 2023-08-25 17:44:01,651 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:44:01,652 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:44:09,656 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1017; msg=ECONNREFUSED
# 2023-08-25 17:44:09,660 | 17182 | [open_context_base.py] _connect_sync:287: Connect fail: conn_id=1018; msg=ECONNREFUSED
# 2023-08-25 17:44:09,660 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
# 2023-08-25 17:44:09,662 | 17182 | [open_context_base.py] _wait_reconnect:482: Wait reconnect in 8 seconds: host=127.0.0.1; port=11111;
